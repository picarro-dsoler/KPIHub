# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from pathlib import Path
import os
import sys
import pandas as pd
# Find KPIHub root (directory containing lib/tables), then import lib.* as a package.
_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *
# Out:
# EU1_Conn created successfully
# EU2_Conn created successfully
# DataHub_Conn created successfully
# US_Conn created successfully

# %%
# Query all customer IDs from the KPI_Customer table
customer_df = KPI_Customer.query_table({'db_path': DB_PATH})
customer_df
# Out:
#                               CustomerId                      Name  \
# 0   4A8FDDAD-482F-DF96-E655-3A065AC4817B                      DEPA
# 1   BD4D080B-1D12-D329-ABD0-39FEB9804E98                    Cadent
# 2   B15EED6C-3E86-302A-357F-3A182BA15005      Gas Networks Ireland
# 3   027114F8-DDB7-C0D0-1398-3A173A08C9BE  Wales and West Utilities
# 4   04084EC0-7411-9D73-827A-3A02EF041CC0                   ADRIGAS
# 5   B7F78B52-D80F-DDEE-5C36-39F97B7A1C60                     Aemme
# 6   03F0CC2A-4D6B-00CE-755E-39EC4E48CDA8                 APRETIGAS
# 7   2A481970-03D6-CE08-7055-3A12CAFE9643                     ASTEA
# 8   4B7750C4-F89F-736D-FB37-3A205FCD0946             Condotte Nord
# 9   D70A7F5E-5A7C-AFD3-CB50-39FEB47BD8FC                   GEI spa
# 10  BD89B089-8351-7E82-1E91-3A205AF1CD8F                Gigas Rete
# 11  16406801-F98E-ED30-5004-3A200D2D75E9                    M Reti
# 12  AF547A63-7008-AA14-32A4-39F191A8520D                   Reti-MT
# 13  A7EE6B7F-F63A-BC5D-80CB-3A160F2CCB61                  SEAB spa
# 14  30057338-4868-C593-1097-3A1E5CEFDCBD                       AIL
# 15  66F061EF-A719-C32A-62DE-3A1D2336530D              ASPM Energia
# 16  531A2106-6518-4036-2149-3A1E38EB4F30         CBL Distribuzione
# 17  CE2B766E-3CE2-6669-C245-3A205FB42991                       MEA
# 18  A0E1D9F8-5D76-4D98-D118-3A1DF725F3C1            V Reti Spoleto
# 19  6ADC7AE0-ED1D-17E8-C4BF-39FFCB8488E2               AMG Palermo
# 20  3FBC78C9-CEF3-C6CB-4E20-3A02D6A2F1C2                   Centria
# 21  427A5394-0476-CB94-7EA0-39ED91F59944                  Novareti
# 22  F49DD290-D6FD-482E-72A5-3A0E2D71A098              AMGAS Foggia
# 23  89888D87-2C23-2DCB-59D2-39F51ED2E3CC                     IRETI
# 24  911690A2-EF00-A3EE-27AD-3A18E4833EDC           Salerno Energia
# 25  CFFB9000-94BD-BA72-B352-39EBA962116D                   ITALGAS
# 26  B511B372-18D7-E520-1328-39F05C8E531A           Toscana Energia
#
#                 ShortName DBLocation                 LastUpdated
# 0                    DEPA        EU2  2026-06-11 12:22:16.672607
# 1                  Cadent        EU2  2026-06-11 12:22:16.682686
# 2      GasNetworksIreland        EU1  2026-06-11 12:22:16.718525
# 3   WalesandWestUtilities        EU1  2026-06-11 12:22:16.729598
# 4                 ADRIGAS        EU2  2026-06-11 12:22:16.741766
# 5                   Aemme        EU2  2026-06-11 12:22:16.752131
# 6               APRETIGAS        EU2  2026-06-11 12:22:16.761428
# 7                   ASTEA        EU1  2026-06-11 12:22:16.772244
# 8            CondotteNord        EU1  2026-06-11 12:22:16.784191
# 9                  GEIspa        EU2  2026-06-11 12:22:16.789482
# 10              GigasRete        EU1  2026-06-11 12:22:16.799333
# 11                  MReti        EU1  2026-06-11 12:22:16.809061
# 12                Reti-MT        EU2  2026-06-11 12:22:16.812896
# 13                SEABspa        EU1  2026-06-11 12:22:16.817919
# 14                    AIL        EU1  2026-06-11 12:22:16.822443
# 15            ASPMEnergia        EU1  2026-06-11 12:22:16.832281
# 16       CBLDistribuzione        EU1  2026-06-11 12:22:16.841609
# 17                    MEA        EU1  2026-06-11 12:22:16.846020
# 18           VRetiSpoleto        EU1  2026-06-11 12:22:16.855384
# 19             AMGPalermo        EU2  2026-06-11 12:22:16.864799
# 20                Centria        EU2  2026-06-11 12:22:16.868228
# 21               Novareti        EU2  2026-06-11 12:22:16.876650
# 22            AMGASFoggia        EU2  2026-06-11 12:22:16.885450
# 23                  IRETI        EU2  2026-06-11 12:22:16.889509
# 24         SalernoEnergia        EU1  2026-06-11 12:22:16.899112
# 25                ITALGAS        EU2  2026-06-11 12:22:16.903038
# 26         ToscanaEnergia        EU2  2026-06-11 12:22:16.911520

# %%
utlization_df = pd.DataFrame({'CustomerId': customer_df[customer_df['Name'] == 'Cadent']['CustomerId'],'WorkingHours': 7,'WorkingDays': 7, 'BaseSurveyorCount': 25})
KPI_Utilization.update_table(arguments = {'DataFrame': utlization_df, 'PrimaryKey': 'CustomerId', 'db_path': DB_PATH})
