# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from pathlib import Path
import os
import sys

# Find KPIHub root (directory containing lib/tables), then import lib.* as a package.
_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *
# Out:
# EU1_Conn created successfully
# EU2_Conn created successfully
# DataHub_Conn created successfully
# US_Conn created successfully
# EU1_PROD_Conn created successfully
# EU2_PROD_Conn created successfully
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 19
#      16 from locallib.query import *
#      18 from lib.tables.IngesterTables import *
# ---> 19 from lib.handlers.CustomerHandler import *
#      20 from lib.config import *
#      21 from lib.KPIHubConnection import *
#
# File ~/personal-repos/KPIHub/lib/handlers/CustomerHandler.py:16
#      14 from tables.IngesterTables import *
#      15 from config import *
# ---> 16 from lib.KPIHubConnection import *
#      17 import pandas as pd
#      18 from datetime import datetime
#
# File ~/personal-repos/KPIHub/lib/KPIHubConnection.py:31
#      29 # Ensure path to DB is relative to this file's directory
#      30 db_path = os.path.abspath(os.path.join(os.path.dirname(__file__), "..", DB_PATH))
# ---> 31 KPIHub_Conn = SQLiteConnection(db_path)
#
# File ~/personal-repos/KPIHub/lib/KPIHubConnection.py:27, in SQLiteConnection.__init__(self, host)
#      25 self.host = host
#      26 self.dbtype = 'sqlite'
# ---> 27 self.engine = connect_sqlite(host)
#
# File ~/personal-repos/KPIHub/lib/KPIHubConnection.py:19, in connect_sqlite(db_path)
#      17 conn = sqlite3.connect(db_path, timeout=30, check_same_thread=False)
#      18 conn.execute("PRAGMA busy_timeout = 30000")
# ---> 19 conn.execute("PRAGMA journal_mode = WAL")
#      20 return conn
#
# DatabaseError: malformed database schema (9806435F-4319-249E-C81F-3A205F47E0F0)

# %%
import pandas as pd
customer_info_path = "CustomerInfo.csv"
customer_info_df = pd.read_csv(customer_info_path)

# %%
for _, customer in customer_info_df.iterrows():
    print(customer['CustomerName'])
    KPI_Customer.query_table({'db_path': DB_PATH})
    add_customer(customer['CustomerName'], CONN_DICT[customer['DBLocation']])
    print('Customer added')
    KPI_Customer.query_table({'db_path': DB_PATH})
    add_customer_utilization(
        customer['CustomerName'],
        customer['WorkingHours'],
        customer['WorkingDays'],
        customer['BaseSurveyors'],

    )
    print('Utilization added')
    KPI_Utilization.query_table({'db_path': DB_PATH})
    current_year = datetime.now().year
    default_por_start_date = f'01-01-{current_year}'
    default_por_end_date = f'31-12-{current_year}'
    add_por(
        customer_name = customer['CustomerName'],
        year = 2026,
        value = customer['POR'] if pd.notna(customer['POR']) else 0,
        StartingDate = customer['PORStartingDate'] if pd.notna(customer['PORStartingDate']) else default_por_start_date,
        EndingDate = customer['POREndingDate'] if pd.notna(customer['POREndingDate']) else default_por_end_date,
        Description = ''
   
    )
    print('POR added')
    KPI_POR.query_table({'db_path': DB_PATH})
    add_output_excel_location(customer['CustomerName'], customer['OutputExcelFolder'], KPIHub_Conn)
    KPI_OutputExcelLocation.query_table({'db_path': DB_PATH}) 
    print('Output Excel Location added')
# Out:
# Avacon
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Westnetz
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Syna
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# NBB
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# EWE
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# ENBW
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Thuega Energienetze
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Energieversorgung Filstal
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# E-NETZ SUDHESSEN
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Netz Niederösterreich
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Stedin
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Gas Networks Ireland
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Wales and West Utilities
# Customer added
# Utilization added
# POR added
# Output Excel Location added
# Cadent
# Customer added
# Utilization added
# POR added
# Output Excel Location added

# %%
KPI_POR.query_table({'db_path': DB_PATH})
# Out:
#                               CustomerId  Year         StartingDate  \
# 0   ED346655-AAF7-B2E7-43E2-3A10E455E700  2026  2026-01-01 00:00:00
# 1   C6565AAF-5251-1DBE-8D39-3A1F45B580A9  2026  2026-01-01 00:00:00
# 2   93A15FC7-DCB8-4BE9-1224-3A1F698B9C1F  2026  2026-01-01 00:00:00
# 3   A1E8BEC0-6A89-9454-137B-3A0A41825A09  2026  2026-01-01 00:00:00
# 4   7D9E66E1-6EE8-27D6-76B4-3A10E451DD30  2026  2026-01-01 00:00:00
# 5   8AABFD1C-862E-CF1E-5545-3A0EF16CBB61  2026  2026-01-01 00:00:00
# 6   B39ACD5B-3AB6-42D2-78D5-3A10F69CAA68  2026  2026-01-01 00:00:00
# 7   5DDE747E-0AAD-B45F-8039-3A1897DBC43F  2026  2026-01-01 00:00:00
# 8   E5F6C480-6796-9A6E-79DE-3A0EF1744B1C  2026  2026-01-01 00:00:00
# 9   7460AB4D-648E-297D-6073-3A145CB49DBC  2026  2026-01-01 00:00:00
# 10  FBBE8BA6-DF46-EF84-CE4D-3A20E60CED9D  2026  2026-01-01 00:00:00
# 11  B15EED6C-3E86-302A-357F-3A182BA15005  2026  2026-04-01 00:00:00
# 12  027114F8-DDB7-C0D0-1398-3A173A08C9BE  2026  2026-04-01 00:00:00
# 13  BD4D080B-1D12-D329-ABD0-39FEB9804E98  2026  2026-04-01 00:00:00
#
#              EndingDate Description     Value Unit                 LastUpdated
# 0   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.223785
# 1   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.273353
# 2   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.329601
# 3   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.382137
# 4   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.427973
# 5   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.470621
# 6   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.521669
# 7   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.579248
# 8   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.625430
# 9   2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.670873
# 10  2026-12-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.706383
# 11  2027-03-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.748515
# 12  2027-03-31 00:00:00                   0.0   Km  2026-07-14 14:11:55.788819
# 13  2027-03-31 00:00:00              127000.0   Km  2026-07-14 14:11:55.830211

# %%
KPI_Utilization.query_table({'db_path': DB_PATH})
# Out:
#                               CustomerId  WorkingDays  WorkingHours  \
# 0   BD4D080B-1D12-D329-ABD0-39FEB9804E98            7             7
# 1   B15EED6C-3E86-302A-357F-3A182BA15005            6             8
# 2   ED346655-AAF7-B2E7-43E2-3A10E455E700            5             6
# 3   C6565AAF-5251-1DBE-8D39-3A1F45B580A9            5             6
# 4   93A15FC7-DCB8-4BE9-1224-3A1F698B9C1F            5             6
# 5   A1E8BEC0-6A89-9454-137B-3A0A41825A09            5             6
# 6   7D9E66E1-6EE8-27D6-76B4-3A10E451DD30            5             6
# 7   8AABFD1C-862E-CF1E-5545-3A0EF16CBB61            5             6
# 8   B39ACD5B-3AB6-42D2-78D5-3A10F69CAA68            5             6
# 9   5DDE747E-0AAD-B45F-8039-3A1897DBC43F            5             6
# 10  E5F6C480-6796-9A6E-79DE-3A0EF1744B1C            5             6
# 11  7460AB4D-648E-297D-6073-3A145CB49DBC            5             6
# 12  FBBE8BA6-DF46-EF84-CE4D-3A20E60CED9D            5             6
# 13  027114F8-DDB7-C0D0-1398-3A173A08C9BE            6             8
#
#     BaseSurveyorCount Description                 LastUpdated
# 0                25.0        None  2026-07-14 14:11:55.823027
# 1                 NaN        None  2026-07-14 14:11:55.739893
# 2                 NaN        None  2026-07-14 14:11:55.215453
# 3                 NaN        None  2026-07-14 14:11:55.262509
# 4                 NaN        None  2026-07-14 14:11:55.319081
# 5                 NaN        None  2026-07-14 14:11:55.372649
# 6                 NaN        None  2026-07-14 14:11:55.418978
# 7                 NaN        None  2026-07-14 14:11:55.460424
# 8                 NaN        None  2026-07-14 14:11:55.509000
# 9                 NaN        None  2026-07-14 14:11:55.571092
# 10                NaN        None  2026-07-14 14:11:55.617392
# 11                NaN        None  2026-07-14 14:11:55.661604
# 12                NaN        None  2026-07-14 14:11:55.698425
# 13                NaN        None  2026-07-14 14:11:55.781658
