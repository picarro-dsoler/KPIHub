# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from pathlib import Path
import os
from os.path import join
import sys

# Find KPIHub root (directory containing lib/tables), then import lib.* as a package.
_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.slack import *
from locallib.etl import Loggers
from locallib.pandas import *
from locallib.box import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *
from lib.query.bank import *

from datetime import date
from datetime import timedelta
# Out:
# EU1_Conn created successfully
# EU2_Conn created successfully
# DataHub_Conn created successfully
# US_Conn created successfully
# EU1_PROD_Conn created successfully
# EU2_PROD_Conn created successfully

# %%
Query(query = "SELECT * FROM KPI_PeakAboveSAT").execute(KPIHub_Conn)
# Out:
#                                CustomerId PeakName  \
# 0    BD4D080B-1D12-D329-ABD0-39FEB9804E98  P6B43EB
# 1    BD4D080B-1D12-D329-ABD0-39FEB9804E98  P225B6C
# 2    BD4D080B-1D12-D329-ABD0-39FEB9804E98  P9842F8
# 3    BD4D080B-1D12-D329-ABD0-39FEB9804E98  P72D2F4
# 4    BD4D080B-1D12-D329-ABD0-39FEB9804E98  P8DDD4F
# ..                                    ...      ...
# 819  BD4D080B-1D12-D329-ABD0-39FEB9804E98  P2D9AAC
# 820  BD4D080B-1D12-D329-ABD0-39FEB9804E98  P782F92
# 821  BD4D080B-1D12-D329-ABD0-39FEB9804E98  PB451D8
# 822  BD4D080B-1D12-D329-ABD0-39FEB9804E98  P308223
# 823  BD4D080B-1D12-D329-ABD0-39FEB9804E98  PBC8183
#
#                                    PeakId                 Date  ReportYear  \
# 0    6B43EB72-6407-481E-AED4-B10A13FE2CA4  2026-07-08 00:00:00        2026
# 1    225B6CD7-31F0-4CFE-9AB9-C4052594305E  2026-07-08 00:00:00        2026
# 2    9842F877-EEA2-43F2-B318-39FC1178AD34  2026-07-08 00:00:00        2026
# 3    72D2F44C-0B0F-4D04-BD60-122A700FF257  2026-07-08 00:00:00        2026
# 4    8DDD4F7C-CA53-4F6D-9A3E-A06E2C4981B5  2026-07-08 00:00:00        2026
# ..                                    ...                  ...         ...
# 819  2D9AAC2C-BE6A-4D66-AF39-871D5C813B4C  2026-07-08 00:00:00        2026
# 820  782F92AB-C9FF-4F50-AFC9-55672C4E4A07  2026-07-08 00:00:00        2026
# 821  B451D831-0AE4-4ACB-88DD-91BDFE08572F  2026-07-08 00:00:00        2026
# 822  30822327-55B6-4AF1-B444-5A083DD4A061  2026-07-08 00:00:00        2026
# 823  BC818344-DB13-4B9F-A83E-FC1831CCCDE2  2026-07-08 00:00:00        2026
#
#      WeekNumber Disposition LocalTime  \
# 0            28           1  04:20:02
# 1            28           1  03:48:58
# 2            28           1  03:29:30
# 3            28           1  03:04:36
# 4            28           1  02:45:36
# ..          ...         ...       ...
# 819          28           1  23:36:51
# 820          28           1  23:15:53
# 821          28           1  23:13:48
# 822          28           1  22:43:04
# 823          28           1  22:16:49
#
#                                           BoundaryName   BoundaryRegion  \
# 0    B26 - 9607 - Warrington - St. Helens - Haydock #1       North West
# 1    B26 - 2218 - Derwent - East Staffordshire - Et...    East Midlands
# 2    B26 - 9586 - Cambridgeshire - South Cambridges...  East of England
# 3              B26 - 5209 - Bolton - Oldham - St Marys       North West
# 4    B26 - 9607 - Warrington - St. Helens - Haydock #1       North West
# ..                                                 ...              ...
# 819  B26 - 9607 - Warrington - St. Helens - Haydock #1       North West
# 820  B26 - 9607 - Warrington - St. Helens - Haydock #1       North West
# 821  B26 - 8687 - Birmingham - Birmingham - Glebe F...    West Midlands
# 822  B26 - 8687 - Birmingham - Birmingham - Glebe F...    West Midlands
# 823  B26 - 2692 - South Herts - Three Rivers - Penn...  East of England
#
#      EmissionRate  PeakGpsLatitude  PeakGpsLongitude        Easting  \
# 0       41.692215        53.472544         -2.686435  354534.037913
# 1       21.318378        52.825858         -1.619926  425707.304841
# 2       43.368294        52.194669          0.199963  550464.888469
# 3       22.490378        53.546215         -2.099616  393496.670650
# 4       22.150018        53.484525         -2.668900  355710.440384
# ..            ...              ...               ...            ...
# 819     45.257644        53.472505         -2.686483  354530.792427
# 820     28.994795        53.472514         -2.686216  354548.500799
# 821     22.948760        52.478789         -1.781467  414939.258416
# 822     21.631016        52.478779         -1.781669  414925.595885
# 823     25.569672        51.634029         -0.497496  504083.743352
#
#           Northing                       UserName  \
# 0    397531.791999      Glynn.Evans@cadentgas.com
# 1    325437.475314       rav.khaira@cadentgas.com
# 2    257439.955561         alan.lee@cadentgas.com
# 3    405513.209046  Dean.Pilkington@cadentgas.com
# 4    398853.648712      Glynn.Evans@cadentgas.com
# ..             ...                            ...
# 819  397527.559892      Glynn.Evans@cadentgas.com
# 820  397528.370689      Glynn.Evans@cadentgas.com
# 821  286784.907654    michael.while@cadentgas.com
# 822  286783.787541    michael.while@cadentgas.com
# 823  193870.961114   Khushal.Hirani@cadentgas.com
#
#                       SurveyorUnit AnalyzerSerialNumber  \
# 0    Cadent Surveyor #06 - LM75XVG            RFADS2357
# 1    Cadent Surveyor #11 - LL75ZZJ            RFADS2094
# 2    Cadent Surveyor #07 - LO75SWX            RFADS2361
# 3    Cadent Surveyor #23 - LM75YJF            RFADS2413
# 4    Cadent Surveyor #06 - LM75XVG            RFADS2357
# ..                             ...                  ...
# 819  Cadent Surveyor #06 - LM75XVG            RFADS2357
# 820  Cadent Surveyor #06 - LM75XVG            RFADS2357
# 821  Cadent Surveyor #03 - LO75GFG            RFADS2178
# 822  Cadent Surveyor #03 - LO75GFG            RFADS2178
# 823  Cadent Surveyor #10 - LL75ZZF            RFADS2367
#
#                                              Hyperlink  \
# 0    https://pcubed2.eu.picarro.com/Live/Survey/1b9...
# 1    https://pcubed2.eu.picarro.com/Live/Survey/d34...
# 2    https://pcubed2.eu.picarro.com/Live/Survey/5eb...
# 3    https://pcubed2.eu.picarro.com/Live/Survey/a79...
# 4    https://pcubed2.eu.picarro.com/Live/Survey/9c2...
# ..                                                 ...
# 819  https://pcubed2.eu.picarro.com/Live/Survey/f74...
# 820  https://pcubed2.eu.picarro.com/Live/Survey/84c...
# 821  https://pcubed2.eu.picarro.com/Live/Survey/f30...
# 822  https://pcubed2.eu.picarro.com/Live/Survey/8c3...
# 823  https://pcubed2.eu.picarro.com/Live/Survey/42d...
#
#                     LastUpdated
# 0    2026-07-09 11:47:14.919088
# 1    2026-07-09 11:47:14.919088
# 2    2026-07-09 11:47:14.919088
# 3    2026-07-09 11:47:14.919088
# 4    2026-07-09 11:47:14.919088
# ..                          ...
# 819  2026-07-09 11:47:14.919088
# 820  2026-07-09 11:47:14.919088
# 821  2026-07-09 11:47:14.919088
# 822  2026-07-09 11:47:14.919088
# 823  2026-07-09 11:47:14.919088
#
# [824 rows x 20 columns]

# %%
Query(query = 'SELECT * FROM KPI_Customer').execute(KPIHub_Conn)
# Out:
#                              CustomerId    Name ShortName DBLocation  \
# 0  BD4D080B-1D12-D329-ABD0-39FEB9804E98  Cadent    Cadent        EU2
#
#                   LastUpdated
# 0  2026-07-09 00:31:55.520053

# %%
Query(query = "SELECT * FROM KPI_OutputExcelLocation").execute(KPIHub_Conn)
# Out:
#                              CustomerId   BoxFolderId  \
# 0  BD4D080B-1D12-D329-ABD0-39FEB9804E98  375691804502
#
#                   LastUpdated
# 0  2026-07-09 12:10:39.410629

# %%
Query(query = "SELECT DISTINCT KPIId FROM KPI_Data").execute(KPIHub_Conn)
# Out:
#                              KPIId
# 0                          FOVMain
# 1              ReportAssetLengthKm
# 2             AssetCoveredLengthKm
# 3               DistributionPipeKm
# 4        DistributionPipeCoveredKm
# 5                    ServicePipeKm
# 6             ServicePipeCoveredKm
# 7                      ReportCount
# 8                        LisaCount
# 9                     EmissionRate
# 10                         B0Count
# 11                         B1Count
# 12                        Bm1Count
# 13                        Bm2Count
# 14                         NGCount
# 15                         PGCount
# 16                     Not_NGCount
# 17                     LisaDensity
# 18            InstatanoeusEmission
# 19                       B0Density
# 20                       B1Density
# 21                      Bm1Density
# 22                      Bm2Density
# 23                       NGDensity
# 24                       PGDensity
# 25                         B0Share
# 26                         B1Share
# 27                        Bm1Share
# 28                        Bm2Share
# 29                         NGShare
# 30                         PGShare
# 31                     Not_NGShare
# 32             SurveyDurationHours
# 33             TargetDurationHours
# 34             CustomerUtilization
# 35            StarndardUtilization
# 36                  TotalSurveyors
# 37         ProductivityPerSurveyor
# 38                     SurveyCount
# 39                      AvgSpeedKm
# 40                   SurveysCarDay
# 41                        IdleTime
# 42                       DaysCount
# 43             TotalDrivenLengthKm
# 44                    DrivingRatio
# 45               NightDrivenLength
# 46                 DayDrivenLength
# 47                      NightRatio
# 48                        DayRatio
# 49               PeakAboveSATCount
# 50  CumulativeAssetCoveredLengthKm
# 51                             POR
# 52               CurrentCompletion
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
