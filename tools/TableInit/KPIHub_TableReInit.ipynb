# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from pathlib import Path
import os
import sys

_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *
# Out:
# EU1_Conn created successfully
# EU2_Conn created successfully
# DataHub_Conn created successfully
# US_Conn created successfully

# %%
#Customer Tables
KPI_Customer.create_table(arguments={'db_path': DB_PATH})

#Summary Tables
KPI_ReportSummary.create_table(arguments={'db_path': DB_PATH})
KPI_EmissionSourceSummary.create_table(arguments={'db_path': DB_PATH})
KPI_SurveySummary.create_table(arguments={'db_path': DB_PATH})

# %%
q = Query(query = f"SELECT * FROM KPI_ReportSummary")
q.execute(KPIHub_Conn)
# Out:
#                                    ReportId  \
# 0      20FFD28C-F999-9048-8819-3A217575EF64
# 1      9B367009-D8DD-ABBE-7829-3A20ABCFA077
# 2      1D7486A9-B1DB-3D95-9650-3A204F581C79
# 3      593A8351-2A6D-1302-8E19-3A0DAABFF5CC
# 4      67A33323-2FFD-F791-38D2-3A19E97B85E7
# ...                                     ...
# 15333  727F1DB5-6445-26F4-B5C6-3A2137F3D141
# 15334  FE83CC32-EE1F-709E-2D39-3A2160B35745
# 15335  6A5EE70D-1129-81AF-41F8-3A217FD4C78B
# 15336  BA0ECE8A-BB00-A009-D8D5-3A2185472F9A
# 15337  B3430D73-57A8-AF03-C347-3A218F29327C
#
#                                  CustomerId ReportName  \
# 0      4A8FDDAD-482F-DF96-E655-3A065AC4817B  CR-20FFD2
# 1      4A8FDDAD-482F-DF96-E655-3A065AC4817B  CR-9B3670
# 2      4A8FDDAD-482F-DF96-E655-3A065AC4817B  CR-1D7486
# 3      4A8FDDAD-482F-DF96-E655-3A065AC4817B  CR-593A83
# 4      4A8FDDAD-482F-DF96-E655-3A065AC4817B  CR-67A333
# ...                                     ...        ...
# 15333  B511B372-18D7-E520-1328-39F05C8E531A  CR-727F1D
# 15334  B511B372-18D7-E520-1328-39F05C8E531A  CR-FE83CC
# 15335  B511B372-18D7-E520-1328-39F05C8E531A  CR-6A5EE7
# 15336  B511B372-18D7-E520-1328-39F05C8E531A  CR-BA0ECE
# 15337  B511B372-18D7-E520-1328-39F05C8E531A  CR-B3430D
#
#                        ReportDate  ReportYear  ReportMonth  ReportWeek  \
# 0      2026-05-26 07:56:35.047000        2026            5          22
# 1      2026-04-17 04:11:15.447000        2026            4          16
# 2             2026-03-30 05:15:39        2026            3          14
# 3      2023-09-15 11:21:32.877000        2023            9          37
# 4      2025-05-16 04:16:19.943000        2025            5          20
# ...                           ...         ...          ...         ...
# 15333  2026-05-14 09:17:37.473000        2026            5          20
# 15334  2026-05-22 07:11:37.797000        2026            5          21
# 15335  2026-05-28 08:16:22.923000        2026            5          22
# 15336  2026-05-29 09:39:26.747000        2026            5          22
# 15337  2026-05-31 07:42:53.563000        2026            5          23
#
#        ReportAssetLengthKm  AssetCoveredLengthKm  DistributionPipeKm  ...  \
# 0                 1.489897              1.407251            1.414147  ...
# 1                42.826012             42.757175           32.391317  ...
# 2                42.546992             42.408135           35.623590  ...
# 3                19.189209             18.674974                 NaN  ...
# 4                41.990845             41.846395           38.834566  ...
# ...                    ...                   ...                 ...  ...
# 15333            37.599731             31.312630           37.599731  ...
# 15334            48.401155             40.205834           48.401155  ...
# 15335            37.860384             36.621197           37.860384  ...
# 15336            60.762601             60.111133           60.762601  ...
# 15337            73.515647             67.741281           73.515647  ...
#
#        ServicePipeKm  ServicePipeCoveredKm  \
# 0           0.075750              0.075750
# 1          10.434695             10.404549
# 2           6.923403              6.923403
# 3                NaN                   NaN
# 4           3.156279              3.116732
# ...              ...                   ...
# 15333            NaN                   NaN
# 15334            NaN                   NaN
# 15335            NaN                   NaN
# 15336            NaN                   NaN
# 15337            NaN                   NaN
#
#                                     BoundaryName  \
# 0                                    B26 - W 111
# 1                                     B26 - S 46
# 2                                    B26 - D1 S4
# 3                                     B22 - W 40
# 4                                     B25 - C 75
# ...                                          ...
# 15333  B25 - FIRENZE 1: SCARPERIA E SAN PIERO #2
# 15334   B25 - PISA: CASTIGLIONE DELLA PESCAIA #2
# 15335                  B25 - PISTOIA: PISTOIA #6
# 15336      B25 - FIRENZE 2: MONTELUPO FIORENTINO
# 15337          B25 - FIRENZE 2: CASTELFIORENTINO
#
#                           BoundaryType       BoundaryMode    BoundaryPlant  \
# 0                          Attica 2026  customer boundary           Attica
# 1                          Attica 2026  customer boundary           Attica
# 2                           Thess 2026  customer boundary            Thess
# 3                     EDA Attikis 2022  customer boundary             None
# 4                          Attica 2025  customer boundary           Attica
# ...                                ...                ...              ...
# 15333  2025 Toscana Energia boundaries  customer boundary  Toscana Energia
# 15334  2025 Toscana Energia boundaries  customer boundary  Toscana Energia
# 15335  2025 Toscana Energia boundaries  customer boundary  Toscana Energia
# 15336  2025 Toscana Energia boundaries  customer boundary  Toscana Energia
# 15337  2025 Toscana Energia boundaries  customer boundary  Toscana Energia
#
#       BoundarySubplant BoundaryRegion BoundarySubRegion  \
# 0                 None         Attica                 W
# 1                 None         Attica                 S
# 2                 None          Thess                D1
# 3                 None           None              None
# 4                 None         Attica                 C
# ...                ...            ...               ...
# 15333             None      Firenze 1              None
# 15334             None           Pisa              None
# 15335             None        Pistoia              None
# 15336             None      Firenze 2              None
# 15337             None      Firenze 2              None
#
#                       LastUpdated
# 0      2026-06-11 12:22:30.637142
# 1      2026-06-11 12:22:30.637142
# 2      2026-06-11 12:22:30.637142
# 3      2026-06-11 12:22:30.637142
# 4      2026-06-11 12:22:30.637142
# ...                           ...
# 15333  2026-06-11 12:23:32.069116
# 15334  2026-06-11 12:23:32.069116
# 15335  2026-06-11 12:23:32.069116
# 15336  2026-06-11 12:23:32.069116
# 15337  2026-06-11 12:23:32.069116
#
# [15338 rows x 21 columns]
