# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import os
import sys

_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *

# %%
#Customer Tables
#KPI_Customer.create_table(arguments={'db_path': DB_PATH})

#Summary Tables
KPI_ReportSummary.create_table(arguments={'db_path': DB_PATH})
KPI_EmissionSourceSummary.reinit_table(arguments={'db_path': DB_PATH})
#KPI_Utilization.reinit_table(arguments={'db_path': DB_PATH})
#KPI_SurveySummary.create_table(arguments={'db_path': DB_PATH})
# Out:
# CREATE TABLE IF NOT EXISTS KPI_EmissionSourceSummary (ReportId uniqueidentifier, EmissionRate float, EmissionRateLPM uniqueidentifier, RepresentativeEmissionRate float, RepresentativeEmissionRateLPM float, LisaCount int, B0Count int, B1Count int, Bm1Count int, Bm2Count int, B0RepEmissionRateLPM float, B1RepEmissionRateLPM float, Bm1RepEmissionRateLPM float, Bm2RepEmissionRateLPM float, B0RepEmissionRate float, B1RepEmissionRate float, Bm1RepEmissionRate float, Bm2RepEmissionRate float, Not_NGCount int, PGCount int, NGCount int, LastUpdated datetime, PRIMARY KEY (ReportId))
# CREATE TABLE IF NOT EXISTS KPI_Utilization (CustomerId uniqueidentifier, WorkingDays int, WorkingHours int, BaseSurveyorCount int, Description nvarchar, LastUpdated datetime, PRIMARY KEY (CustomerId))

# %%
q = Query(query = f"SELECT * FROM KPI_EmissionSourceSummary")
q.execute(KPIHub_Conn)
# Out:
# Empty DataFrame
# Columns: [ReportId, EmissionRate, EmissionRateLPM, RepresentativeEmissionRate, RepresentativeEmissionRateLPM, LisaCount, B0Count, B1Count, Bm1Count, Bm2Count, B0RepEmissionRateLPM, B1RepEmissionRateLPM, Bm1RepEmissionRateLPM, Bm2RepEmissionRateLPM, B0RepEmissionRate, B1RepEmissionRate, Bm1RepEmissionRate, Bm2RepEmissionRate, Not_NGCount, PGCount, NGCount, LastUpdated]
# Index: []
#
# [0 rows x 22 columns]
