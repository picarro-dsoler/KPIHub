# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from pathlib import Path
import os
import sys

_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *
# Out:
# EU1_Conn created successfully
# EU2_Conn created successfully
# DataHub_Conn created successfully
# US_Conn created successfully
# EU1_PROD_Conn created successfully
# EU2_PROD_Conn created successfully

# %%
#KPI Defintion table
KPI_Definition.reinit_table(arguments={'db_path': DB_PATH})
KPI_Data.reinit_table(arguments={'db_path': DB_PATH})
KPI_Utilization.reinit_table(arguments={'db_path': DB_PATH})

#Customer Tables
KPI_Customer.reinit_table(arguments={'db_path': DB_PATH})

#KPI_SurveySummary Table
#KPI_SurveySummary.reinit_table(arguments = {'db_path': DB_PATH, 'pair_key': ['SurveyId', 'ReportId']})

#Summary Tables
KPI_ReportSummary.reinit_table(arguments={'db_path': DB_PATH})
KPI_EmissionSourceSummary.reinit_table(arguments={'db_path': DB_PATH})
KPI_SurveySummary.reinit_table(arguments = {'db_path': DB_PATH, 'extra_sql': "CREATE UNIQUE INDEX IF NOT EXISTS SurveyReport_Unique ON KPI_SurveySummary (SurveyId, ReportId)"})
# Out:
# CREATE TABLE IF NOT EXISTS KPI_Definition (Name nvarchar, Unit nvarchar, Formula nvarchar, Description nvarchar, LastUpdated datetime, PRIMARY KEY (Name))
# CREATE TABLE IF NOT EXISTS KPI_Data (Id nvarchar, KPIId nvarchar, CustomerId uniqueidentifier, BoundaryRegion nvarchar, Year int, PeriodType int, PeriodValue int, Value nvarchar, DataType nvarchar, LastUpdated datetime, PRIMARY KEY (Id))
# CREATE TABLE IF NOT EXISTS KPI_Utilization (CustomerId uniqueidentifier, WorkingDays int, WorkingHours int, BaseSurveyorCount int, Description nvarchar, LastUpdated datetime, PRIMARY KEY (CustomerId))
# CREATE TABLE IF NOT EXISTS KPI_Customer (CustomerId uniqueidentifier, Name nvarchar, ShortName nvarchar, DBLocation nvarchar, LastUpdated datetime, PRIMARY KEY (CustomerId))
# CREATE TABLE IF NOT EXISTS KPI_ReportSummary (ReportId uniqueidentifier, CustomerId uniqueidentifier, ReportName nvarchar, ReportDate datetime, ReportYear int, ReportMonth int, ReportWeek int, ReportAssetLengthKm float, AssetCoveredLengthKm float, DistributionPipeKm float, DistributionPipeCoveredKm float, ServicePipeKm float, ServicePipeCoveredKm float, BoundaryName nvarchar, BoundaryType nvarchar, BoundaryMode nvarchar, BoundaryPlant nvarchar, BoundarySubplant nvarchar, BoundaryRegion nvarchar, BoundarySubRegion nvarchar, LastUpdated datetime, PRIMARY KEY (ReportId))
# CREATE TABLE IF NOT EXISTS KPI_EmissionSourceSummary (ReportId uniqueidentifier, EmissionRate float, LisaCount int, B0Count int, B1Count int, Bm1Count int, Bm2Count int, Not_NGCount int, PGCount int, NGCount int, LastUpdated datetime, PRIMARY KEY (ReportId))
# CREATE TABLE IF NOT EXISTS KPI_SurveySummary (SurveyId uniqueidentifier, ReportId uniqueidentifier, SurveyorUnit nvarchar, SurveyDurationMinutes float, StartHour int, StartTime datetime, StartEpoch bigint, EndTime datetime, EndEpoch bigint, StartDay date, EndDay date, LateralRotation nvarchar, NumberOfPeaks int, DaySegments int, NightSegments int, ActiveSegments int, IdleSegments int, TotalSegments int, TotalKilometers float, DayKilometers float, NightKilometers float, SegmentDurationMinutes float, IdleTimeMinutes float, ActiveTimeMinutes float, AvgSpeedKm float, LastUpdated datetime)

# %%
q = Query(query = f"SELECT * FROM KPI_EmissionSourceSummary")
q.execute(KPIHub_Conn)
# Out:
# Empty DataFrame
# Columns: [ReportId, EmissionRate, LisaCount, B0Count, B1Count, Bm1Count, Bm2Count, Not_NGCount, PGCount, NGCount, LastUpdated]
# Index: []
