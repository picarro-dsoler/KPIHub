# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f

# %%
from pathlib import Path
import os
import sys

_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *
from lib.KPIHubConnection import *
# Out:
# EU1_Conn created successfully
# EU2_Conn created successfully
# DataHub_Conn created successfully
# US_Conn created successfully

# %%
#KPI Defintion table
#KPI_Definition.reinit_table(arguments={'db_path': DB_PATH})
#KPI_Data.reinit_table(arguments={'db_path': DB_PATH})
#KPI_Utilization.reinit_table(arguments={'db_path': DB_PATH})

#Customer Tables
KPI_Customer.reinit_table(arguments={'db_path': DB_PATH})

#KPI_SurveySummary Table
#KPI_SurveySummary.reinit_table(arguments = {'db_path': DB_PATH, 'pair_key': ['SurveyId', 'ReportId']})

#Summary Tables
#KPI_ReportSummary.reinit_table(arguments={'db_path': DB_PATH})
#KPI_EmissionSourceSummary.reinit_table(arguments={'db_path': DB_PATH})
#KPI_SurveySummary.reinit_table(arguments = {'db_path': DB_PATH, 'extra_sql': "CREATE UNIQUE INDEX IF NOT EXISTS SurveyReport_Unique ON KPI_SurveySummary (SurveyId, ReportId)"})
# Out:
# CREATE TABLE IF NOT EXISTS KPI_Customer (CustomerId uniqueidentifier, Name nvarchar, ShortName nvarchar, DBLocation nvarchar, LastUpdated datetime, PRIMARY KEY (CustomerId))

# %%
q = Query(query = f"SELECT * FROM KPI_Data")
q.execute(KPIHub_Conn)
# Out:
#                              Id     KPIId  \
# 0      FOVMain_Cadent_Y2023_W14   FOVMain
# 1      FOVMain_Cadent_Y2023_W15   FOVMain
# 2      FOVMain_Cadent_Y2023_W16   FOVMain
# 3      FOVMain_Cadent_Y2023_W17   FOVMain
# 4      FOVMain_Cadent_Y2023_W19   FOVMain
# ...                         ...       ...
# 7963  DayRatio_Cadent_Y2026_W21  DayRatio
# 7964  DayRatio_Cadent_Y2026_W22  DayRatio
# 7965  DayRatio_Cadent_Y2026_W23  DayRatio
# 7966  DayRatio_Cadent_Y2026_W24  DayRatio
# 7967  DayRatio_Cadent_Y2026_W25  DayRatio
#
#                                 CustomerId  Year PeriodType  PeriodValue  \
# 0     BD4D080B-1D12-D329-ABD0-39FEB9804E98  2023     Weekly           14
# 1     BD4D080B-1D12-D329-ABD0-39FEB9804E98  2023     Weekly           15
# 2     BD4D080B-1D12-D329-ABD0-39FEB9804E98  2023     Weekly           16
# 3     BD4D080B-1D12-D329-ABD0-39FEB9804E98  2023     Weekly           17
# 4     BD4D080B-1D12-D329-ABD0-39FEB9804E98  2023     Weekly           19
# ...                                    ...   ...        ...          ...
# 7963  BD4D080B-1D12-D329-ABD0-39FEB9804E98  2026     Weekly           21
# 7964  BD4D080B-1D12-D329-ABD0-39FEB9804E98  2026     Weekly           22
# 7965  BD4D080B-1D12-D329-ABD0-39FEB9804E98  2026     Weekly           23
# 7966  BD4D080B-1D12-D329-ABD0-39FEB9804E98  2026     Weekly           24
# 7967  BD4D080B-1D12-D329-ABD0-39FEB9804E98  2026     Weekly           25
#
#      Value DataType                 LastUpdated
# 0     None     None  2026-06-15 09:30:51.906175
# 1     None     None  2026-06-15 09:30:51.906175
# 2     None     None  2026-06-15 09:30:51.906175
# 3     None     None  2026-06-15 09:30:51.906175
# 4     None     None  2026-06-15 09:30:51.906175
# ...    ...      ...                         ...
# 7963  0.62     None  2026-06-15 09:31:08.283606
# 7964  0.19     None  2026-06-15 09:31:08.283606
# 7965  0.26     None  2026-06-15 09:31:08.283606
# 7966  0.14     None  2026-06-15 09:31:08.283606
# 7967   0.0     None  2026-06-15 09:31:08.283606
#
# [7968 rows x 9 columns]
