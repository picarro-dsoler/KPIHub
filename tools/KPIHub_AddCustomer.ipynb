# %%
# %load_ext autoreload
# %autoreload 2
# %reset -f
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import os
import sys

# Find KPIHub root (directory containing lib/tables), then import lib.* as a package.
_here = Path.cwd().resolve()
_root = next((p for p in [_here, *list(_here.parents)[:12]] if (p / "lib" / "tables").is_dir()), None)
if _root is None:
    raise FileNotFoundError(
        f"Could not find KPIHub root (folder containing lib/tables). cwd={Path.cwd()!r}"
    )
sys.path.insert(0, str(_root))
os.chdir(_root)

from locallib.picarrodb import *
from locallib.query import *

from lib.tables.CustomerTables import *
from lib.tables.IngesterTables import *
from lib.handlers.CustomerHandler import *
from lib.config import *

# %%
add_customer('Cadent',EU2_Conn)
add_customer('Italgas',EU2_Conn)
add_customer('Toscana Energia',EU2_Conn)
add_customer('DEPA',EU2_Conn)

# %%
query = 'SELECT * FROM KPI_Customer'
q = Query(query = query)
q.execute(KPIHub_Conn)
# Out:
#                                      Id             Name       ShortName  \
# 0  BD4D080B-1D12-D329-ABD0-39FEB9804E98           Cadent          Cadent
# 1  CFFB9000-94BD-BA72-B352-39EBA962116D          ITALGAS         ITALGAS
# 2  B511B372-18D7-E520-1328-39F05C8E531A  Toscana Energia  ToscanaEnergia
# 3  4A8FDDAD-482F-DF96-E655-3A065AC4817B             DEPA            DEPA
#
#   DBLocation                 LastUpdated
# 0        EU2  2026-05-20 12:54:11.021611
# 1        EU2  2026-05-20 12:54:11.086137
# 2        EU2  2026-05-20 12:54:11.152138
# 3        EU2  2026-05-20 12:54:11.221725
